# %% [markdown]
# <a href="https://colab.research.google.com/github/MrUsmanAshraf/Assignment/blob/main/Assignment_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gtts -q
# !pip install playsound -q
# Out:
#   Preparing metadata (setup.py) ... done
#   Building wheel for playsound (setup.py) ... done

# %%
# !pip install -U -q google-genai
from google import genai

# %%
from google.colab import userdata
import os
os.environ['GOOGLE_API_KEY']=userdata.get('GOOGLE_API_KEY')

# %%
import time
from google import genai
from google.genai import Client

client: Client = genai.Client()
MODEL: str = "Gemini 2.0 Flash Experimental"

video_file_name = "/content/intro.mp4"

# %%
def upload_video(video_file_name):
  video_file=client.files.upload(path=video_file_name)
  while video_file.state == "PROCESSING":
    print("Processing...")
    time.sleep(10)
    video_file=client.files.get(name=video_file.name or "")

  if video_file.state == "ERROR":
    raise Exception(f"Error uploading video: {video_file.error}")

  print(f'video procesing complete : '+ (video_file.uri or " "))
  return video_file

my_video=upload_video(video_file_name)
# Out:
# Processing...
# video procesing complete : https://generativelanguage.googleapis.com/v1beta/files/ovmt2k0jc204

# %%
from google.genai.types import Content,Part
prompt="""For each scene in this video generate caption that describe the scene along with any spkoen text place
in qutation marks place each caption into an object with timecode of the caption in the video"""
video=my_video
response = client.models.generate_content(
    model=model,
    contents=[
        Content(
            role="user",
            parts=[Part.from_uri (file_uri=video.uri or "", mime_type=video.mime_type or "")]
                ),
        prompt,

           ]
)
print(response.text)
# Out:
# ```json
# [
#   {
#     "timecode": "00:00",
#     "caption": "A woman wearing a black coat over a red and white patterned shirt is smiling and waving with a white background with alphabet chart to her right and a drawing board saying 'Hello I am Teacher' behind her. She is wearing a headset with a microphone and speaking. She says, \"Hello, My name is Patricia Espiritu. I am 24 years old from the Philippines.\""
#   },
#  {
#     "timecode": "00:08",
#     "caption": "The woman continues speaking looking straight into the camera with her mouth open as she speaks and says, \"I have a bachelor's degree in Business Administration major in Financial Management.\""
#   },
#   {
#     "timecode": "00:14",
#     "caption": "The woman continues speaking looking straight into the camera with her mouth open as she speaks and says, \"And I have a TESOL and TEFL certification.\""
#    },
# {
#     "timecode": "00:17",
#     "caption": "The woman continues speaking looking straight into the camera with her mouth open as she speaks and says, \"I am a bank employee for almost four years now where I was at customer service for two years.\""
#   },
# {
#    "timecode": "00:24",
#     "caption": "The woman continues speaking looking straight into the camera with her mouth open as she speaks and says, \"I love teaching kids and I am very excited to make a great impact in your company.\""
#   }
# ]
# ```

# %%
from gtts import gTTS
from playsound import playsound
from IPython.display import Audio

tts=gTTS(text="Hello my name is Usman ashraf and I am student of PIAIC Lahore and I am learning Agentic ai",lang='en')

with open ("output.mp3","wb") as f:
       for chunk in tts.stream():
           f.write(chunk)

display(Audio("output.mp3",autoplay=True))
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
